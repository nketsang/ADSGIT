# %%
import pandas as pd
import plotly.express as px 
from plotly import graph_objects as go
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-90bf79efb672> in <module>
#       1 import pandas as pd
# ----> 2 import plotly.express as px
#       3 from plotly import graph_objects as go
#
# ModuleNotFoundError: No module named 'plotly'

# %%
 pip install plotly==4.14.3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import plotly.express as px 
from plotly import graph_objects as go

# %%
px.data.gapminder()
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
df=px.data.gapminder()

# %%
df.isnull().any()
# Out:
# country      False
# continent    False
# year         False
# lifeExp      False
# pop          False
# gdpPercap    False
# iso_alpha    False
# iso_num      False
# dtype: bool

# %%
df_asiacountry=df[["country", "continent","year","lifeExp"]]
df_asiacountry
# Out:
#           country continent  year  lifeExp
# 0     Afghanistan      Asia  1952   28.801
# 1     Afghanistan      Asia  1957   30.332
# 2     Afghanistan      Asia  1962   31.997
# 3     Afghanistan      Asia  1967   34.020
# 4     Afghanistan      Asia  1972   36.088
# ...           ...       ...   ...      ...
# 1699     Zimbabwe    Africa  1987   62.351
# 1700     Zimbabwe    Africa  1992   60.377
# 1701     Zimbabwe    Africa  1997   46.809
# 1702     Zimbabwe    Africa  2002   39.989
# 1703     Zimbabwe    Africa  2007   43.487
#
# [1704 rows x 4 columns]

# %%
df_asiaONLY=df_asiacountry[df_asiacountry.continent.str.contains("Asia",case=False)]
df_asiaONLY
# Out:
#           country continent  year  lifeExp
# 0     Afghanistan      Asia  1952   28.801
# 1     Afghanistan      Asia  1957   30.332
# 2     Afghanistan      Asia  1962   31.997
# 3     Afghanistan      Asia  1967   34.020
# 4     Afghanistan      Asia  1972   36.088
# ...           ...       ...   ...      ...
# 1675  Yemen, Rep.      Asia  1987   52.922
# 1676  Yemen, Rep.      Asia  1992   55.599
# 1677  Yemen, Rep.      Asia  1997   58.020
# 1678  Yemen, Rep.      Asia  2002   60.308
# 1679  Yemen, Rep.      Asia  2007   62.698
#
# [396 rows x 4 columns]

# %%
df1=df_asiaONLY.groupby("country")["lifeExp"].mean()
df1.head()
# Out:
# country
# Afghanistan    37.478833
# Bahrain        65.605667
# Bangladesh     49.834083
# Cambodia       47.902750
# China          61.785140
# Name: lifeExp, dtype: float64

# %%
df_asiaONLY.groupby("year")["lifeExp"].mean()
# Out:
# year
# 1952    46.314394
# 1957    49.318544
# 1962    51.563223
# 1967    54.663640
# 1972    57.319269
# 1977    59.610556
# 1982    62.617939
# 1987    64.851182
# 1992    66.537212
# 1997    68.020515
# 2002    69.233879
# 2007    70.728485
# Name: lifeExp, dtype: float64

# %%
df_asiaONLY.groupby(["country","year"])["lifeExp"].mean()
# Out:
# country      year
# Afghanistan  1952    28.801
#              1957    30.332
#              1962    31.997
#              1967    34.020
#              1972    36.088
#                       ...
# Yemen, Rep.  1987    52.922
#              1992    55.599
#              1997    58.020
#              2002    60.308
#              2007    62.698
# Name: lifeExp, Length: 396, dtype: float64

# %%
#count  
import seaborn as sns; sns.set(color_codes=True)
df1 = sns.load_dataset("df1")
sns.catplot(x="country", y="lifeExp", hue="kind", data= df1, kind="bar")

# %% [markdown]
# # QUESTION 2
# #Deviation in GDP of each country in Europe and South America.

# %%
df_deviation=df[["country", "continent","year","gdpPercap"]]
df_asiacountry.head()
# Out:
#        country continent  year  lifeExp
# 0  Afghanistan      Asia  1952   28.801
# 1  Afghanistan      Asia  1957   30.332
# 2  Afghanistan      Asia  1962   31.997
# 3  Afghanistan      Asia  1967   34.020
# 4  Afghanistan      Asia  1972   36.088

# %%
df.groupby("continent")["year"].mean()
# Out:
# continent
# Africa      1979.5
# Americas    1979.5
# Asia        1979.5
# Europe      1979.5
# Oceania     1979.5
# Name: year, dtype: float64

# %%
df4=df_deviation[df_deviation.continent.str.contains("Americas",case=False)]
df4
# Out:
#         country continent  year     gdpPercap
# 48    Argentina  Americas  1952   5911.315053
# 49    Argentina  Americas  1957   6856.856212
# 50    Argentina  Americas  1962   7133.166023
# 51    Argentina  Americas  1967   8052.953021
# 52    Argentina  Americas  1972   9443.038526
# ...         ...       ...   ...           ...
# 1639  Venezuela  Americas  1987   9883.584648
# 1640  Venezuela  Americas  1992  10733.926310
# 1641  Venezuela  Americas  1997  10165.495180
# 1642  Venezuela  Americas  2002   8605.047831
# 1643  Venezuela  Americas  2007  11415.805690
#
# [300 rows x 4 columns]

# %%
dfeurope=df_deviation[df_deviation.continent.str.contains("Europe",case=False)]
dfeurope
# Out:
#              country continent  year     gdpPercap
# 12           Albania    Europe  1952   1601.056136
# 13           Albania    Europe  1957   1942.284244
# 14           Albania    Europe  1962   2312.888958
# 15           Albania    Europe  1967   2760.196931
# 16           Albania    Europe  1972   3313.422188
# ...              ...       ...   ...           ...
# 1603  United Kingdom    Europe  1987  21664.787670
# 1604  United Kingdom    Europe  1992  22705.092540
# 1605  United Kingdom    Europe  1997  26074.531360
# 1606  United Kingdom    Europe  2002  29478.999190
# 1607  United Kingdom    Europe  2007  33203.261280
#
# [360 rows x 4 columns]

# %%
df_merge=pd.merge(dfeurope,df4,how="outer")
df_merge.head()
# Out:
#    country continent  year    gdpPercap
# 0  Albania    Europe  1952  1601.056136
# 1  Albania    Europe  1957  1942.284244
# 2  Albania    Europe  1962  2312.888958
# 3  Albania    Europe  1967  2760.196931
# 4  Albania    Europe  1972  3313.422188

# %%
df_merge["gdpPercap"].std()
# Out:
# 8921.715013928668

# %%
# create a pivot table 
df_mergeAL = df4.pivot("country","year", "gdpPercap")
df_mergeAL.head()
# Out:
# year               1952          1957          1962          1967  \
# country
# Argentina   5911.315053   6856.856212   7133.166023   8052.953021
# Bolivia     2677.326347   2127.686326   2180.972546   2586.886053
# Brazil      2108.944355   2487.365989   3336.585802   3429.864357
# Canada     11367.161120  12489.950060  13462.485550  16076.588030
# Chile       3939.978789   4315.622723   4519.094331   5106.654313
#
# year               1972          1977          1982          1987  \
# country
# Argentina   9443.038526  10079.026740   8997.897412   9139.671389
# Bolivia     2980.331339   3548.097832   3156.510452   2753.691490
# Brazil      4985.711467   6660.118654   7030.835878   7807.095818
# Canada     18970.570860  22090.883060  22898.792140  26626.515030
# Chile       5494.024437   4756.763836   5095.665738   5547.063754
#
# year               1992          1997          2002          2007
# country
# Argentina   9308.418710  10967.281950   8797.640716  12779.379640
# ...

# %%
#gdp of each country in america
import seaborn as sns; sns.set(color_codes=True)
ax1 = sns.heatmap(df_mergeAL)

# %%
# create a pivot table 
df_mergeAL1 = dfeurope.pivot("country","year", "gdpPercap")
df_mergeAL1.head()
# Out:
# year                           1952         1957          1962          1967  \
# country
# Albania                 1601.056136  1942.284244   2312.888958   2760.196931
# Austria                 6137.076492  8842.598030  10750.721110  12834.602400
# Belgium                 8343.105127  9714.960623  10991.206760  13149.041190
# Bosnia and Herzegovina   973.533195  1353.989176   1709.683679   2172.352423
# Bulgaria                2444.286648  3008.670727   4254.337839   5577.002800
#
# year                            1972          1977          1982  \
# country
# Albania                  3313.422188   3533.003910   3630.880722
# Austria                 16661.625600  19749.422300  21597.083620
# Belgium                 16672.143560  19117.974480  20979.845890
# Bosnia and Herzegovina   2860.169750   3528.481305   4126.613157
# Bulgaria                 6597.494398   7612.240438   8224.191647
#
# year                            1987          1992          1997  \
# country
# ...

# %%
#gdp of each country in europe
import seaborn as sns; sns.set(color_codes=True)
ax2 = sns.heatmap(df_mergeAL1)

# %%
#df_merge.groupby(["country","continent"])["gdpPercap"].mean()

# %%
# create a pivot table 
#df_mergeAl1 = df_mergeALL.pivot("country", "continent", "gdpPercap")
#df_mergeAL1.head()

# %% [markdown]
# # QUESTION 3
# The change in population of each African country in the last 3 decades.

# %%
dfsort=df_africa.sort_values(by=['year'], ascending=False)
dfsort
# Out:
#             country continent  year  lifeExp       pop    gdpPercap iso_alpha  \
# 1703       Zimbabwe    Africa  2007   43.487  12311143   469.709298       ZWE
# 467           Egypt    Africa  2007   71.338  80264543  5581.180998       EGY
# 827           Kenya    Africa  2007   54.110  35610177  1463.249282       KEN
# 635   Guinea-Bissau    Africa  2007   46.388   1472041   579.231743       GNB
# 623          Guinea    Africa  2007   56.007   9947814   942.654211       GIN
# ...             ...       ...   ...      ...       ...          ...       ...
# 948            Mali    Africa  1952   33.685   3838168   452.336981       MLI
# 924          Malawi    Africa  1952   36.256   2917802   369.165080       MWI
# 912      Madagascar    Africa  1952   36.681   4762912  1443.011715       MDG
# 888         Liberia    Africa  1952   38.480    863308   575.572996       LBR
# 900           Libya    Africa  1952   42.723   1019729  2387.548060       LBY
#
#       iso_num
# 1703      716
# ...

# %%
dfsort=df_africa.sort_values(by=['country'], ascending=False)
dfsort
# Out:
#        country continent  year  lifeExp       pop    gdpPercap iso_alpha  \
# 1703  Zimbabwe    Africa  2007   43.487  12311143   469.709298       ZWE
# 1697  Zimbabwe    Africa  1977   57.674   6642107   685.587682       ZWE
# 1692  Zimbabwe    Africa  1952   48.451   3080907   406.884115       ZWE
# 1693  Zimbabwe    Africa  1957   50.469   3646340   518.764268       ZWE
# 1694  Zimbabwe    Africa  1962   52.358   4277736   527.272182       ZWE
# ...        ...       ...   ...      ...       ...          ...       ...
# 32     Algeria    Africa  1992   67.744  26298373  5023.216647       DZA
# 33     Algeria    Africa  1997   69.152  29072015  4797.295051       DZA
# 34     Algeria    Africa  2002   70.994  31287142  5288.040382       DZA
# 35     Algeria    Africa  2007   72.301  33333216  6223.367465       DZA
# 24     Algeria    Africa  1952   43.077   9279525  2449.008185       DZA
#
#       iso_num
# 1703      716
# 1697      716
# 1692      716
# 1693      716
# ...

# %%
dfsort.groupby(["country","year"])["pop"].mean()
#dfsort.head(20)
# Out:
# country   year
# Algeria   1952     9279525
#           1957    10270856
#           1962    11000948
#           1967    12760499
#           1972    14760787
#                     ...
# Zimbabwe  1987     9216418
#           1992    10704340
#           1997    11404948
#           2002    11926563
#           2007    12311143
# Name: pop, Length: 624, dtype: int64

# %%
df_africa["year"].max()
# Out:
# 2007

# %%
df_africa["year"].min()
# Out:
# 1952

# %%
df_africa07=df[df.continent.str.contains("Africa",case=False)].query("year==2007")
df_africa07.head()
# Out:
#           country continent  year  lifeExp       pop     gdpPercap iso_alpha  \
# 35        Algeria    Africa  2007   72.301  33333216   6223.367465       DZA
# 47         Angola    Africa  2007   42.731  12420476   4797.231267       AGO
# 131         Benin    Africa  2007   56.728   8078314   1441.284873       BEN
# 167      Botswana    Africa  2007   50.728   1639131  12569.851770       BWA
# 203  Burkina Faso    Africa  2007   52.295  14326203   1217.032994       BFA
#
#      iso_num
# 35        12
# 47        24
# 131      204
# 167       72
# 203      854

# %%
df_africa97=df[df.continent.str.contains("Africa",case=False)].query("year==1997")
df_africa97.head()
# Out:
#           country continent  year  lifeExp       pop    gdpPercap iso_alpha  \
# 33        Algeria    Africa  1997   69.152  29072015  4797.295051       DZA
# 45         Angola    Africa  1997   40.963   9875024  2277.140884       AGO
# 129         Benin    Africa  1997   54.777   6066080  1232.975292       BEN
# 165      Botswana    Africa  1997   52.556   1536536  8647.142313       BWA
# 201  Burkina Faso    Africa  1997   50.324  10352843   946.294962       BFA
#
#      iso_num
# 33        12
# 45        24
# 129      204
# 165       72
# 201      854

# %%
df_africa87=df[df.continent.str.contains("Africa",case=False)].query("year==1987")
df_africa87.head()
# Out:
#           country continent  year  lifeExp       pop    gdpPercap iso_alpha  \
# 31        Algeria    Africa  1987   65.799  23254956  5681.358539       DZA
# 43         Angola    Africa  1987   39.906   7874230  2430.208311       AGO
# 127         Benin    Africa  1987   52.337   4243788  1225.856010       BEN
# 163      Botswana    Africa  1987   63.622   1151184  6205.883850       BWA
# 199  Burkina Faso    Africa  1987   49.557   7586551   912.063142       BFA
#
#      iso_num
# 31        12
# 43        24
# 127      204
# 163       72
# 199      854

# %%
df_merge2=pd.merge(df_africa87,df_africa97,how="outer")
df_merge2.head()
# Out:
#         country continent  year  lifeExp       pop    gdpPercap iso_alpha  \
# 0       Algeria    Africa  1987   65.799  23254956  5681.358539       DZA
# 1        Angola    Africa  1987   39.906   7874230  2430.208311       AGO
# 2         Benin    Africa  1987   52.337   4243788  1225.856010       BEN
# 3      Botswana    Africa  1987   63.622   1151184  6205.883850       BWA
# 4  Burkina Faso    Africa  1987   49.557   7586551   912.063142       BFA
#
#    iso_num
# 0       12
# 1       24
# 2      204
# 3       72
# 4      854

# %%
df_mergeALL=pd.merge(df_merge2,df_africa07,how="outer")
df_mergeALL.head()
# Out:
#         country continent  year  lifeExp       pop    gdpPercap iso_alpha  \
# 0       Algeria    Africa  1987   65.799  23254956  5681.358539       DZA
# 1        Angola    Africa  1987   39.906   7874230  2430.208311       AGO
# 2         Benin    Africa  1987   52.337   4243788  1225.856010       BEN
# 3      Botswana    Africa  1987   63.622   1151184  6205.883850       BWA
# 4  Burkina Faso    Africa  1987   49.557   7586551   912.063142       BFA
#
#    iso_num
# 0       12
# 1       24
# 2      204
# 3       72
# 4      854

# %%
#bar 
#df_mergeALL.catplot(x="", y="pulse", hue="kind", data=exercise, kind="bar")

# %%
# create a pivot table 
df_mergeALL1 = df_mergeALL.pivot("country", "year", "pop")
df_mergeALL1.head()
# Out:
# year              1987      1997      2007
# country
# Algeria       23254956  29072015  33333216
# Angola         7874230   9875024  12420476
# Benin          4243788   6066080   8078314
# Botswana       1151184   1536536   1639131
# Burkina Faso   7586551  10352843  14326203

# %%
import seaborn as sns; sns.set(color_codes=True)
ax = sns.heatmap(df_mergeALL1)
